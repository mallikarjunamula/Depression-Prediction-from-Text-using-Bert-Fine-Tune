# %% [markdown]
# **Deploy Fine Tuned Bert Model**

# %% [markdown]
# * Push the model to huggingface hub.
# * Deploy it on Streamlit cloud.

# %%
# !pip install transformers

# %%
# !pip install huggingface_hub

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification

# %%
#Mounting to google drive
from google.colab import drive
drive.mount('/content/drive/') #force_remount=True
# %cd drive/MyDrive/MyProjects/Depression_BERT_FineTuning
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/MyProjects/Depression_BERT_FineTuning

# %%
#Loading already saved fine tuned bert model.
model = BertForSequenceClassification.from_pretrained("FineTunedBertModel")

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Token is valid.
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
model.push_to_hub("arjunm2305/finetunedBertModelDepression")
# Out:
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# CommitInfo(commit_url='https://huggingface.co/arjunm2305/finetunedBertModelDepression/commit/116bf9fac10ca673ba178f52fdc67fef8f04333c', commit_message='Upload BertForSequenceClassification', commit_description='', oid='116bf9fac10ca673ba178f52fdc67fef8f04333c', pr_url=None, pr_revision=None, pr_num=None)

# %%
#When model is public
model = BertForSequenceClassification.from_pretrained("arjunm2305/finetunedBertModelDepression")

# %%
#When model is declared as private, we need use_auth_token parameter.
model = BertForSequenceClassification.from_pretrained("arjunm2305/finetunedBertModelDepression", use_auth_token='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')
